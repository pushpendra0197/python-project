# %% [markdown]
# #importing Libraries for data reading and manupuation or visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\KINGNICKS-DELL\Downloads\Analysis report on Sale.xlsx")

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
#some attributes related to data set

# %%
np.ndim(df)
np.size(df)
np.shape(df)
# Out:
# (11251, 15)

# %%
np.size(df)
# Out:
# 168765

# %%
np.shape(df)
# Out:
# (11251, 15)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
##AS you see we have different type of column in dataset but two data set are not having any value for that we can enter value
## or drop the column

# %%
df.isnull()
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
##True is showing two column containing null value

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df["Status"][0]="not filled"
# Out:
# C:\Users\KINGNICKS-DELL\AppData\Local\Temp\ipykernel_5792\2817357325.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Status"][0]="not filled"

# %%
df
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df.fillna("notfilled")
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
##we can drop perticular columns also

# %%
df1=df.drop(labels=["Status","unnamed1"],axis=1)

# %%
df1
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
#Using value.count() for checking count of value in columns

# %%
df1["Cust_name"].value_counts()
# Out:
# Cust_name
# Vishakha       42
# Shreyshi       32
# Sudevi         30
# Akshat         29
# Alejandro      28
#                ..
# Sarita          2
# Madan Mohan     2
# Madhav          2
# Laal            1
# Bindu           1
# Name: count, Length: 1250, dtype: int64

# %%
##counting unique customer

# %%
a=df["Cust_name"].unique()

# %%
a
# Out:
# array(['Sanskriti', 'Kartik', 'Bindu', ..., 'Chris', 'Madan Mohan',
#        'Nicole'], dtype=object)

# %%
##showing some statistical function related t =i data
df1.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
df1
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df1["Marital_Status"].replace(0,"yes")
# Out:
# 0        yes
# 1          1
# 2          1
# 3        yes
# 4          1
#         ...
# 11246      1
# 11247    yes
# 11248    yes
# 11249    yes
# 11250    yes
# Name: Marital_Status, Length: 11251, dtype: object

# %%
df2=df1["Marital_Status"].replace(0,"yes")

# %%
df2
# Out:
# 0        yes
# 1          1
# 2          1
# 3        yes
# 4          1
#         ...
# 11246      1
# 11247    yes
# 11248    yes
# 11249    yes
# 11250    yes
# Name: Marital_Status, Length: 11251, dtype: object

# %%
df1
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df1
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df1["Marital_Status"].astype("string")
# Out:
# 0        0
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 11246    1
# 11247    0
# 11248    0
# 11249    0
# 11250    0
# Name: Marital_Status, Length: 11251, dtype: string

# %%
df1
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df3=df1["Marital_Status"].replace(0,"yes")

# %%
df1
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df3
# Out:
# 0        yes
# 1          1
# 2          1
# 3        yes
# 4          1
#         ...
# 11246      1
# 11247    yes
# 11248    yes
# 11249    yes
# 11250    yes
# Name: Marital_Status, Length: 11251, dtype: object

# %%
#now i am adding conditional column on the basis of value

# %%
df1["Maritial_status"]=["Yes" if Marital_Status==0   else "NO" for Marital_Status in df1["Marital_Status"]]

# %%
df1
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df2=df1.drop(labels=["Marital_Status"],axis=1)

# %%
#using query for filtering the data

# %%
df2.query('Gender=="F" & Age==28')
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age           State  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28     Maharashtra
# 46     1000728       Breyer  P00113942      F     26-35   28  Andhra Pradesh
# 65     1004728        Larry  P00037042      F     26-35   28           Delhi
# 83     1006040         Pond  P00271242      F     26-35   28           Delhi
# 125    1002445        Shiva  P00184042      F     26-35   28           Delhi
# ...        ...          ...        ...    ...       ...  ...             ...
# 11112  1004389        Dario  P00119742      F     26-35   28           Delhi
# 11136  1001169  DeVincentis  P00048442      F     26-35   28     Maharashtra
# 11138  1002611       Rachna  P00178142      F     26-35   28     Maharashtra
# 11190  1005874       Irving  P00184942      F     26-35   28           Delhi
# 11201  1000877      Sanjova  P00023142      F     26-35   28  Madhya Pradesh
#
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Maritial_status   11251 non-null  object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 1.2+ MB

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Maritial_status   11251 non-null  object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 1.2+ MB

# %%
df2
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age           State  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28     Maharashtra
# 1      1000732       Kartik  P00110942      F     26-35   35  Andhra Pradesh
# 2      1001990        Bindu  P00118542      F     26-35   35   Uttar Pradesh
# 3      1001425       Sudevi  P00237842      M      0-17   16       Karnataka
# 4      1000588         Joni  P00057942      M     26-35   28         Gujarat
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19     Maharashtra
# 11247  1004089  Reichenbach  P00171342      M     26-35   33         Haryana
# 11248  1001209        Oshin  P00201342      F     36-45   40  Madhya Pradesh
# 11249  1004023       Noonan  P00059442      M     36-45   37       Karnataka
# 11250  1002744      Brumley  P00281742      F     18-25   19     Maharashtra
#
# ...

# %%
df2.query('Gender=="F" & Age==28')
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age           State  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28     Maharashtra
# 46     1000728       Breyer  P00113942      F     26-35   28  Andhra Pradesh
# 65     1004728        Larry  P00037042      F     26-35   28           Delhi
# 83     1006040         Pond  P00271242      F     26-35   28           Delhi
# 125    1002445        Shiva  P00184042      F     26-35   28           Delhi
# ...        ...          ...        ...    ...       ...  ...             ...
# 11112  1004389        Dario  P00119742      F     26-35   28           Delhi
# 11136  1001169  DeVincentis  P00048442      F     26-35   28     Maharashtra
# 11138  1002611       Rachna  P00178142      F     26-35   28     Maharashtra
# 11190  1005874       Irving  P00184942      F     26-35   28           Delhi
# 11201  1000877      Sanjova  P00023142      F     26-35   28  Madhya Pradesh
#
# ...

# %%
df1
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df2
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age           State  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28     Maharashtra
# 1      1000732       Kartik  P00110942      F     26-35   35  Andhra Pradesh
# 2      1001990        Bindu  P00118542      F     26-35   35   Uttar Pradesh
# 3      1001425       Sudevi  P00237842      M      0-17   16       Karnataka
# 4      1000588         Joni  P00057942      M     26-35   28         Gujarat
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19     Maharashtra
# 11247  1004089  Reichenbach  P00171342      M     26-35   33         Haryana
# 11248  1001209        Oshin  P00201342      F     36-45   40  Madhya Pradesh
# 11249  1004023       Noonan  P00059442      M     36-45   37       Karnataka
# 11250  1002744      Brumley  P00281742      F     18-25   19     Maharashtra
#
# ...

# %%
df2["Occupation"].value_counts()
# Out:
# Occupation
# IT Sector          1588
# Healthcare         1408
# Aviation           1310
# Banking            1139
# Govt                854
# Hospitality         705
# Media               637
# Automobile          566
# Chemical            542
# Lawyer              531
# Retail              501
# Food Processing     423
# Construction        414
# Textile             350
# Agriculture         283
# Name: count, dtype: int64

# %%
# displaying some columns values in the form of graph

# %%
a=df["Cust_name"].value_counts()
a
# Out:
# Cust_name
# Vishakha       42
# Shreyshi       32
# Sudevi         30
# Akshat         29
# Alejandro      28
#                ..
# Sarita          2
# Madan Mohan     2
# Madhav          2
# Laal            1
# Bindu           1
# Name: count, Length: 1250, dtype: int64

# %%
a=sns.countplot(df2,x="Zone")
#adding label for clear value
for  bars in a.containers:
    a.bar_label(bars)

# %%
b=sns.countplot(df2,x=df2["Gender"],hue=df2["Orders"])
for  bars in b.containers:
    b.bar_label(bars)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 b=sns.countplot(df2,x=df2["Gender"],hue=df2["Orders"])
#       2 for  bars in b.containers:
#       3     b.bar_label(bars)
#
# NameError: name 'sns' is not defined

# %%
df2[["Gender","Orders"]].value_counts()
# Out:
# Gender  Orders
# F       2         2014
#         3         1946
#         1         1942
#         4         1940
# M       2          881
#         1          871
#         4          835
#         3          822
# Name: count, dtype: int64

# %%
plt.pie(x=df2["Orders"],labels=df2["Gender"],data=df2)
# Out:
# ([<matplotlib.patches.Wedge at 0x185bf67b890>,
# ...
#   ...],
#  [Text(1.0999999930796318, 0.0001233888582396141, 'F'),
#   Text(1.0999998269907814, 0.0006169442852911951, 'F'),
#   Text(1.0999991626354413, 0.001357277174508896, 'F'),
#   Text(1.099998228385994, 0.001974220776683052, 'M'),
#   Text(1.0999972318535898, 0.0024677752004915324, 'M'),
#   Text(1.0999963391269065, 0.002837940697748877, 'M'),
#   Text(1.0999945744353468, 0.0034548824583102576, 'F'),
#   Text(1.0999924637270844, 0.004071823132096246, 'F'),
#   Text(1.0999910312143815, 0.004441986933984091, 'M'),
#   Text(1.099987792492311, 0.00518231298677795, 'F'),
#   Text(1.0999847129411613, 0.005799249585161929, 'M'),
#   Text(1.0999826991238768, 0.006169410680984616, 'F'),
#   Text(1.099979820266941, 0.00666295771473165, 'F'),
#   Text(1.0999750867672529, 0.007403275719204517, 'M'),
#   Text(1.0999689346116899, 0.008266975820954231, 'M'),
#   Text(1.099964125004185, 0.008883901382721049, 'F'),
# ...

# %%
z=df2["Orders"].value_counts()
z
# Out:
# Orders
# 2    2895
# 1    2813
# 4    2775
# 3    2768
# Name: count, dtype: int64

# %%
df2
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age           State  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28     Maharashtra
# 1      1000732       Kartik  P00110942      F     26-35   35  Andhra Pradesh
# 2      1001990        Bindu  P00118542      F     26-35   35   Uttar Pradesh
# 3      1001425       Sudevi  P00237842      M      0-17   16       Karnataka
# 4      1000588         Joni  P00057942      M     26-35   28         Gujarat
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19     Maharashtra
# 11247  1004089  Reichenbach  P00171342      M     26-35   33         Haryana
# 11248  1001209        Oshin  P00201342      F     36-45   40  Madhya Pradesh
# 11249  1004023       Noonan  P00059442      M     36-45   37       Karnataka
# 11250  1002744      Brumley  P00281742      F     18-25   19     Maharashtra
#
# ...

# %%
df2
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age           State  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28     Maharashtra
# 1      1000732       Kartik  P00110942      F     26-35   35  Andhra Pradesh
# 2      1001990        Bindu  P00118542      F     26-35   35   Uttar Pradesh
# 3      1001425       Sudevi  P00237842      M      0-17   16       Karnataka
# 4      1000588         Joni  P00057942      M     26-35   28         Gujarat
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19     Maharashtra
# 11247  1004089  Reichenbach  P00171342      M     26-35   33         Haryana
# 11248  1001209        Oshin  P00201342      F     36-45   40  Madhya Pradesh
# 11249  1004023       Noonan  P00059442      M     36-45   37       Karnataka
# 11250  1002744      Brumley  P00281742      F     18-25   19     Maharashtra
#
# ...

# %%
df2
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age           State  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28     Maharashtra
# 1      1000732       Kartik  P00110942      F     26-35   35  Andhra Pradesh
# 2      1001990        Bindu  P00118542      F     26-35   35   Uttar Pradesh
# 3      1001425       Sudevi  P00237842      M      0-17   16       Karnataka
# 4      1000588         Joni  P00057942      M     26-35   28         Gujarat
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19     Maharashtra
# 11247  1004089  Reichenbach  P00171342      M     26-35   33         Haryana
# 11248  1001209        Oshin  P00201342      F     36-45   40  Madhya Pradesh
# 11249  1004023       Noonan  P00059442      M     36-45   37       Karnataka
# 11250  1002744      Brumley  P00281742      F     18-25   19     Maharashtra
#
# ...

# %%
d=sns.barplot(x="Zone",y="Amount",data=df2)
for bars in d.containers:
    d.bar_label(bars)

# %%
a=sns.countplot(df2,x="Orders",hue="Zone")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   State             11251 non-null  object
#  7   Zone              11251 non-null  object
#  8   Occupation        11251 non-null  object
#  9   Product_Category  11251 non-null  object
#  10  Orders            11251 non-null  int64
#  11  Amount            11239 non-null  float64
#  12  Maritial_status   11251 non-null  object
# dtypes: float64(1), int64(3), object(9)
# memory usage: 1.1+ MB

# %%
sns.histplot(df2["Orders"])
# Out:
# <Axes: xlabel='Orders', ylabel='Count'>

# %%
plt.pie(df2["Orders"],labels=df2["Occupation"])
# Out:
# ([<matplotlib.patches.Wedge at 0x185dc5ec090>,
# ...
#   ...],
#  [Text(1.0999999930796318, 0.0001233888582396141, 'Healthcare'),
#   Text(1.0999998269907814, 0.0006169442852911951, 'Govt'),
#   Text(1.0999991626354413, 0.001357277174508896, 'Automobile'),
#   Text(1.099998228385994, 0.001974220776683052, 'Construction'),
#   Text(1.0999972318535898, 0.0024677752004915324, 'Food Processing'),
#   Text(1.0999963391269065, 0.002837940697748877, 'Food Processing'),
#   Text(1.0999945744353468, 0.0034548824583102576, 'Lawyer'),
#   Text(1.0999924637270844, 0.004071823132096246, 'IT Sector'),
#   Text(1.0999910312143815, 0.004441986933984091, 'Govt'),
#   Text(1.099987792492311, 0.00518231298677795, 'Media'),
#   Text(1.0999847129411613, 0.005799249585161929, 'Banking'),
#   Text(1.0999826991238768, 0.006169410680984616, 'Retail'),
#   Text(1.099979820266941, 0.00666295771473165, 'IT Sector'),
#   Text(1.0999750867672529, 0.007403275719204517, 'Automobile'),
# ...

# %%
a=df2["Occupation"].value_counts().index
a
# Out:
# Index(['IT Sector', 'Healthcare', 'Aviation', 'Banking', 'Govt', 'Hospitality',
#        'Media', 'Automobile', 'Chemical', 'Lawyer', 'Retail',
#        'Food Processing', 'Construction', 'Textile', 'Agriculture'],
#       dtype='object', name='Occupation')

# %%
b=df2["Orders"].value_counts().values
b
# Out:
# array([2895, 2813, 2775, 2768], dtype=int64)

# %%
sample=df2.sample(20)

# %%
sample
# Out:
#        User_ID Cust_name Product_ID Gender Age Group  Age             State  \
# 314    1004640     Nirja  P00106042      F     26-35   31       Maharashtra
# 4746   1000300   Sissman  P00010742      F     26-35   31  Himachal Pradesh
# 1486   1001023  Kimberly  P00355942      F       55+   82           Haryana
# 3738   1002986     Boyes  P00366442      F     26-35   32         Karnataka
# 7193   1001776  Gannaway  P00057942      F     26-35   35       Maharashtra
# ...        ...       ...        ...    ...       ...  ...               ...
# 3426   1000390   Trafton  P00116142      F     26-35   35         Karnataka
# 6130   1000319     Rohit  P00007842      M     51-55   53       Maharashtra
# 7554   1001449    Dorris  P00178642      F     36-45   45     Uttar Pradesh
# 10523  1001173     Ginny  P00005142      M     26-35   31       Uttarakhand
# 564    1001483   Shardul  P00151742      F     18-25   20     Uttar Pradesh
#
# ...

# %%
plt.pie("Amount",labels="Product_Category",data=sample)
# Out:
# ([<matplotlib.patches.Wedge at 0x185ea9ff150>,
# ...
#  [Text(1.0995277449316334, 0.03222946052228154, 'Clothing & Apparel'),
#   Text(1.0666280881650416, 0.2688950009527666, 'Furniture'),
#   Text(0.8960206277889144, 0.6380807429916373, 'Food'),
#   Text(0.6554646442013892, 0.8833833257436697, 'Food'),
#   Text(0.39621797605865894, 1.026163396076853, 'Clothing & Apparel'),
#   Text(0.12710482795221367, 1.0926318514079838, 'Clothing & Apparel'),
#   Text(-0.1699326368790319, 1.0867947823408701, 'Electronics & Gadgets'),
#   Text(-0.6361716474102919, 0.8973770863083566, 'Food'),
#   Text(-1.0086535179659153, 0.4388827641808041, 'Food'),
#   Text(-1.092710531753329, 0.1264266340426621, 'Clothing & Apparel'),
#   Text(-1.0997085901582007, 0.02531830824250964, 'Household items'),
#   Text(-1.0989926069365379, -0.04706644132322525, 'Clothing & Apparel'),
#   Text(-1.0458481945888933, -0.34088349017685293, 'Food'),
#   Text(-0.8354149415970524, -0.7155989626574327, 'Games & Toys'),
# ...

# %%
z=sns.barplot(x="Amount",y="Product_Category",data=df2)
for bars in z.containers:
    z.bar_label(bars)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[153], line 2
#       1 z=sns.barplot(x="Amount",y="Product_Category",data=df2)
# ----> 2 for bars in z.containers(lenght=1):
#       3     z.bar_label(bars)
#
# TypeError: 'list' object is not callable

# %%
df2.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'State', 'Zone', 'Occupation', 'Product_Category', 'Orders', 'Amount',
#        'Maritial_status'],
#       dtype='object')

# %%
df2["Orders"].value_counts()
# Out:
# Orders
# 2    2895
# 1    2813
# 4    2775
# 3    2768
# Name: count, dtype: int64

# %%
x=df[["Amount","Orders"]].corr()

# %%
sns.heatmap(x.corr().round(2),annot=True)
# Out:
# <Axes: >

# %%
sns.boxplot(data=df2["Orders"])
# Out:
# <Axes: >

# %%
df2["Orders"].describe()
# Out:
# count    11251.000000
# mean         2.489290
# std          1.115047
# min          1.000000
# 25%          1.500000
# 50%          2.000000
# 75%          3.000000
# max          4.000000
# Name: Orders, dtype: float64

# %%
df2
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age           State  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28     Maharashtra
# 1      1000732       Kartik  P00110942      F     26-35   35  Andhra Pradesh
# 2      1001990        Bindu  P00118542      F     26-35   35   Uttar Pradesh
# 3      1001425       Sudevi  P00237842      M      0-17   16       Karnataka
# 4      1000588         Joni  P00057942      M     26-35   28         Gujarat
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19     Maharashtra
# 11247  1004089  Reichenbach  P00171342      M     26-35   33         Haryana
# 11248  1001209        Oshin  P00201342      F     36-45   40  Madhya Pradesh
# 11249  1004023       Noonan  P00059442      M     36-45   37       Karnataka
# 11250  1002744      Brumley  P00281742      F     18-25   19     Maharashtra
#
# ...
